# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

# %%
from kerastuner.tuners import RandomSearch

# %%
df = pd.read_csv("D:\\ml\\dataset\\Real_Combine.csv")

# %%
df.head()   # Air quality index prediction
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
X = df.iloc[:,:-1] # independent variable
y = df.iloc[:,-1] # dependent variable

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='mean_absolute_error',
        metrics=['mean_absolute_error'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='Air Quality Index')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3,random_state=0)

# %%
tuner.search(X_train,y_train,
            epochs=5,
            validation_data=(X_test,y_test))
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |14                |?
# units_0           |448               |?
# units_1           |448               |?
# learning_rate     |0.0001            |?
#
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 1s 39ms/step - loss: nan - mean_absolute_error: nan - val_loss: 99.5623 - val_mean_absolute_error: 99.5623
# Epoch 2/5
# 24/24 [==============================] - 1s 22ms/step - loss: nan - mean_absolute_error: nan - val_loss: 76.0136 - val_mean_absolute_error: 76.0136
# Epoch 3/5
# 24/24 [==============================] - 0s 20ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.0263 - val_mean_absolute_error: 65.0263
# Epoch 4/5
# 24/24 [==============================] - 0s 17ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.6124 - val_mean_absolute_error: 64.6124
# Epoch 5/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.0763 - val_mean_absolute_error: 64.0763
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 105.0317 - val_mean_absolute_error: 105.0317
# Epoch 2/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 99.4126 - val_mean_absolute_error: 99.4126
# Epoch 3/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 76.2023 - val_mean_absolute_error: 76.2023
# Epoch 4/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.3960 - val_mean_absolute_error: 64.3960
# Epoch 5/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.3882 - val_mean_absolute_error: 64.3882
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 104.4516 - val_mean_absolute_error: 104.4516
# Epoch 2/5
# 24/24 [==============================] - 0s 10ms/step - loss: nan - mean_absolute_error: nan - val_loss: 94.6564 - val_mean_absolute_error: 94.6564
# Epoch 3/5
# 24/24 [==============================] - 0s 9ms/step - loss: nan - mean_absolute_error: nan - val_loss: 66.2733 - val_mean_absolute_error: 66.2733
# Epoch 4/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.4247 - val_mean_absolute_error: 65.4247
# Epoch 5/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.1961 - val_mean_absolute_error: 64.1961
#
# Trial 1 Complete [00h 00m 09s]
# val_mean_absolute_error: 64.22020212809245
#
# Best val_mean_absolute_error So Far: 64.22020212809245
# Total elapsed time: 00h 00m 09s
# C:\ProgramData\Anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Search: Running Trial #2
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |13                |14
# units_0           |512               |448
# units_1           |64                |448
# learning_rate     |0.001             |0.0001
# units_2           |288               |32
# units_3           |512               |32
# units_4           |352               |32
# units_5           |352               |32
# units_6           |192               |32
# units_7           |128               |32
# units_8           |480               |32
# units_9           |416               |32
# units_10          |288               |32
# units_11          |288               |32
# units_12          |256               |32
# units_13          |416               |32
#
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 1s 48ms/step - loss: nan - mean_absolute_error: nan - val_loss: 76.7395 - val_mean_absolute_error: 76.7395
# Epoch 2/5
# 24/24 [==============================] - 1s 39ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.1937 - val_mean_absolute_error: 65.1937
# Epoch 3/5
# 24/24 [==============================] - 1s 36ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.8034 - val_mean_absolute_error: 62.8034
# Epoch 4/5
# 24/24 [==============================] - 0s 17ms/step - loss: nan - mean_absolute_error: nan - val_loss: 73.3174 - val_mean_absolute_error: 73.3174
# Epoch 5/5
# 24/24 [==============================] - 1s 35ms/step - loss: nan - mean_absolute_error: nan - val_loss: 61.7435 - val_mean_absolute_error: 61.7435
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 1s 23ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.2889 - val_mean_absolute_error: 63.2889
# Epoch 2/5
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.0676 - val_mean_absolute_error: 63.0676
# Epoch 3/5
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 69.3725 - val_mean_absolute_error: 69.3725
# Epoch 4/5
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.7716 - val_mean_absolute_error: 62.7716
# Epoch 5/5
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 73.9983 - val_mean_absolute_error: 73.9983
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 1s 24ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.5321 - val_mean_absolute_error: 63.5321
# Epoch 2/5
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.1186 - val_mean_absolute_error: 63.1186
# Epoch 3/5
# 24/24 [==============================] - 0s 16ms/step - loss: nan - mean_absolute_error: nan - val_loss: 72.5924 - val_mean_absolute_error: 72.5924
# Epoch 4/5
# 24/24 [==============================] - 1s 34ms/step - loss: nan - mean_absolute_error: nan - val_loss: 59.6368 - val_mean_absolute_error: 59.6368
# Epoch 5/5
# 24/24 [==============================] - 1s 30ms/step - loss: nan - mean_absolute_error: nan - val_loss: 50.5930 - val_mean_absolute_error: 50.5930
#
# Trial 2 Complete [00h 00m 13s]
# val_mean_absolute_error: 58.36935170491537
#
# Best val_mean_absolute_error So Far: 58.36935170491537
# Total elapsed time: 00h 00m 23s
#
# Search: Running Trial #3
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |5                 |13
# units_0           |288               |512
# units_1           |256               |64
# learning_rate     |0.01              |0.001
# units_2           |192               |288
# units_3           |192               |512
# units_4           |512               |352
# units_5           |288               |352
# units_6           |32                |192
# units_7           |256               |128
# units_8           |64                |480
# units_9           |128               |416
# units_10          |288               |288
# units_11          |192               |288
# units_12          |128               |256
# units_13          |384               |416
# C:\ProgramData\Anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 21ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.0034 - val_mean_absolute_error: 65.0034
# Epoch 2/5
# 24/24 [==============================] - 0s 12ms/step - loss: nan - mean_absolute_error: nan - val_loss: 75.6186 - val_mean_absolute_error: 75.6186
# Epoch 3/5
# 24/24 [==============================] - 0s 18ms/step - loss: nan - mean_absolute_error: nan - val_loss: 60.7277 - val_mean_absolute_error: 60.7277
# Epoch 4/5
# 24/24 [==============================] - 0s 15ms/step - loss: nan - mean_absolute_error: nan - val_loss: 47.1905 - val_mean_absolute_error: 47.1905
# Epoch 5/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 44.9280 - val_mean_absolute_error: 44.9280
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 12ms/step - loss: nan - mean_absolute_error: nan - val_loss: 69.7717 - val_mean_absolute_error: 69.7717
# Epoch 2/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.0495 - val_mean_absolute_error: 65.0495
# Epoch 3/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 48.2406 - val_mean_absolute_error: 48.2406
# Epoch 4/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 48.0251 - val_mean_absolute_error: 48.0251
# Epoch 5/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 47.7749 - val_mean_absolute_error: 47.7749
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 11ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.3026 - val_mean_absolute_error: 65.3026
# Epoch 2/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.7724 - val_mean_absolute_error: 63.7724
# Epoch 3/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 71.9518 - val_mean_absolute_error: 71.9518
# Epoch 4/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 48.3443 - val_mean_absolute_error: 48.3443
# Epoch 5/5
# 24/24 [==============================] - 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: 46.7845 - val_mean_absolute_error: 46.7845
#
# Trial 3 Complete [00h 00m 06s]
# val_mean_absolute_error: 46.495792388916016
#
# Best val_mean_absolute_error So Far: 46.495792388916016
# Total elapsed time: 00h 00m 29s
# C:\ProgramData\Anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Search: Running Trial #4
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |4                 |5
# units_0           |32                |288
# units_1           |128               |256
# learning_rate     |0.0001            |0.01
# units_2           |352               |192
# units_3           |256               |192
# units_4           |192               |512
# units_5           |256               |288
# units_6           |224               |32
# units_7           |352               |256
# units_8           |160               |64
# units_9           |512               |128
# units_10          |416               |288
# units_11          |128               |192
# units_12          |32                |128
# units_13          |512               |384
#
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.8843 - val_mean_absolute_error: 65.8843
# Epoch 2/5
# 24/24 [==============================] - 0s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: 66.2145 - val_mean_absolute_error: 66.2145
# Epoch 3/5
# 24/24 [==============================] - 0s 13ms/step - loss: nan - mean_absolute_error: nan - val_loss: 62.9488 - val_mean_absolute_error: 62.9488
# Epoch 4/5
# 24/24 [==============================] - 0s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.5040 - val_mean_absolute_error: 63.5040
# Epoch 5/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.0989 - val_mean_absolute_error: 63.0989
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 11ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.1543 - val_mean_absolute_error: 64.1543
# Epoch 2/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.3209 - val_mean_absolute_error: 63.3209
# Epoch 3/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.4054 - val_mean_absolute_error: 64.4054
# Epoch 4/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.3295 - val_mean_absolute_error: 63.3295
# Epoch 5/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.9752 - val_mean_absolute_error: 63.9752
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 0s 10ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.6777 - val_mean_absolute_error: 65.6777
# Epoch 2/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.5199 - val_mean_absolute_error: 64.5199
# Epoch 3/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.7627 - val_mean_absolute_error: 64.7627
# Epoch 4/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.0898 - val_mean_absolute_error: 65.0898
# Epoch 5/5
# 24/24 [==============================] - 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.4583 - val_mean_absolute_error: 64.4583
#
# Trial 4 Complete [00h 00m 05s]
# val_mean_absolute_error: 63.575995127360024
#
# Best val_mean_absolute_error So Far: 46.495792388916016
# Total elapsed time: 00h 00m 35s
# C:\ProgramData\Anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)
# Search: Running Trial #5
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |16                |5
# units_0           |224               |288
# units_1           |416               |256
# learning_rate     |0.001             |0.01
# units_2           |384               |192
# units_3           |96                |192
# units_4           |480               |512
# units_5           |256               |288
# units_6           |416               |32
# units_7           |320               |256
# units_8           |512               |64
# units_9           |256               |128
# units_10          |224               |288
# units_11          |480               |192
# units_12          |288               |128
# units_13          |352               |384
#
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 1s 48ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.5461 - val_mean_absolute_error: 64.5461
# Epoch 2/5
# 24/24 [==============================] - 1s 39ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.4973 - val_mean_absolute_error: 63.4973
# Epoch 3/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 92.0684 - val_mean_absolute_error: 92.0684
# Epoch 4/5
# 24/24 [==============================] - 1s 24ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.1428 - val_mean_absolute_error: 64.1428
# Epoch 5/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.7822 - val_mean_absolute_error: 63.7822
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 1s 28ms/step - loss: nan - mean_absolute_error: nan - val_loss: 80.4087 - val_mean_absolute_error: 80.4087
# Epoch 2/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 67.3650 - val_mean_absolute_error: 67.3650
# Epoch 3/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.9449 - val_mean_absolute_error: 63.9449
# Epoch 4/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.1540 - val_mean_absolute_error: 64.1540
# Epoch 5/5
# 24/24 [==============================] - 1s 35ms/step - loss: nan - mean_absolute_error: nan - val_loss: 61.6827 - val_mean_absolute_error: 61.6827
# Epoch 1/5
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 24/24 [==============================] - 1s 28ms/step - loss: nan - mean_absolute_error: nan - val_loss: 77.9148 - val_mean_absolute_error: 77.9148
# Epoch 2/5
# 24/24 [==============================] - 0s 20ms/step - loss: nan - mean_absolute_error: nan - val_loss: 64.5644 - val_mean_absolute_error: 64.5644
# Epoch 3/5
# 24/24 [==============================] - 0s 19ms/step - loss: nan - mean_absolute_error: nan - val_loss: 65.3145 - val_mean_absolute_error: 65.3145
# Epoch 4/5
# 24/24 [==============================] - 0s 20ms/step - loss: nan - mean_absolute_error: nan - val_loss: 72.9299 - val_mean_absolute_error: 72.9299
# Epoch 5/5
# 24/24 [==============================] - 0s 20ms/step - loss: nan - mean_absolute_error: nan - val_loss: 63.3523 - val_mean_absolute_error: 63.3523
#
# Trial 5 Complete [00h 00m 13s]
# val_mean_absolute_error: 62.84408696492513
#
# Best val_mean_absolute_error So Far: 46.495792388916016
# Total elapsed time: 00h 00m 48s
# INFO:tensorflow:Oracle triggered exit
# C:\ProgramData\Anaconda3\lib\site-packages\kerastuner\engine\metrics_tracking.py:92: RuntimeWarning: All-NaN axis encountered
#   return np.nanmin(values)

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project\Air Quality Index
# Showing 10 best trials
# Objective(name='val_mean_absolute_error', direction='min')
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 288
# units_1: 256
# learning_rate: 0.01
# units_2: 192
# units_3: 192
# units_4: 512
# units_5: 288
# units_6: 32
# units_7: 256
# units_8: 64
# units_9: 128
# units_10: 288
# units_11: 192
# units_12: 128
# units_13: 384
# Score: 46.495792388916016
# Trial summary
# Hyperparameters:
# num_layers: 13
# units_0: 512
# units_1: 64
# learning_rate: 0.001
# units_2: 288
# units_3: 512
# units_4: 352
# units_5: 352
# units_6: 192
# units_7: 128
# units_8: 480
# units_9: 416
# units_10: 288
# units_11: 288
# units_12: 256
# units_13: 416
# Score: 58.36935170491537
# Trial summary
# Hyperparameters:
# num_layers: 16
# units_0: 224
# units_1: 416
# learning_rate: 0.001
# units_2: 384
# units_3: 96
# units_4: 480
# units_5: 256
# units_6: 416
# units_7: 320
# units_8: 512
# units_9: 256
# units_10: 224
# units_11: 480
# units_12: 288
# units_13: 352
# units_14: 32
# units_15: 32
# Score: 62.84408696492513
# Trial summary
# Hyperparameters:
# num_layers: 4
# units_0: 32
# units_1: 128
# learning_rate: 0.0001
# units_2: 352
# units_3: 256
# units_4: 192
# units_5: 256
# units_6: 224
# units_7: 352
# units_8: 160
# units_9: 512
# units_10: 416
# units_11: 128
# units_12: 32
# units_13: 512
# Score: 63.575995127360024
# Trial summary
# Hyperparameters:
# num_layers: 14
# units_0: 448
# units_1: 448
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# units_9: 32
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# Score: 64.22020212809245
